# %%
import tkinter as tk
from tkinter import *
from math import *

def evaluate(e1):
    res.configure(text = "Ergebnis: " + str(eval(e1.get())))

master = Tk()
master.title('Converter')
Label(master, text='Eingabe im Format: dd:hh:mm').grid(row=0, column=0)
e1 = Entry(master)
e1.grid(row=1, column=0)
e1.bind("<Return>", master)
res = Label(master, text = 'Ausgabe in Minuten').grid(row=3)
Button(master, text='Quit', command=master.destroy).grid(row=4, column=0, sticky=W, pady=4)
Button(master, text='Calculate', ).grid(row=4, column=1, sticky=W, pady=4)
master.mainloop()
